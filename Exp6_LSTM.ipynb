# %%
# Step 1: Load and preprocess IMDb dataset

from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Vocabulary size
vocab_size = 10000

# Load dataset
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)

# Pad sequences (make all reviews same length)
max_len = 200

X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# Check shapes
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# X_train shape: (25000, 200)
# X_test shape: (25000, 200)
# y_train shape: (25000,)
# y_test shape: (25000,)

# %%
# Step 2: LSTM Model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Build model
lstm_model = Sequential()
lstm_model.add(Embedding(input_dim=vocab_size, output_dim=128, input_length=max_len))
lstm_model.add(LSTM(64))
lstm_model.add(Dense(1, activation='sigmoid'))

# Compile model
lstm_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Model summary
lstm_model.summary()

# Train model
history_lstm = lstm_model.fit(
    X_train, y_train,
    epochs=5,
    batch_size=32,
    validation_split=0.2
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 120ms/step - accuracy: 0.7987 - loss: 0.4300 - val_accuracy: 0.8600 - val_loss: 0.3372
# Epoch 2/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 75s 120ms/step - accuracy: 0.9001 - loss: 0.2531 - val_accuracy: 0.8544 - val_loss: 0.3537
# Epoch 3/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 121ms/step - accuracy: 0.9344 - loss: 0.1741 - val_accuracy: 0.8502 - val_loss: 0.3648
# Epoch 4/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 121ms/step - accuracy: 0.9546 - loss: 0.1264 - val_accuracy: 0.8386 - val_loss: 0.4519
# Epoch 5/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 76s 122ms/step - accuracy: 0.9689 - loss: 0.0879 - val_accuracy: 0.8526 - val_loss: 0.4419

# %%
# Step 3: Evaluate LSTM

loss_lstm, acc_lstm = lstm_model.evaluate(X_test, y_test)

print("LSTM Test Loss:", loss_lstm)
print("LSTM Test Accuracy:", acc_lstm)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8514 - loss: 0.4421
# LSTM Test Loss: 0.4421128034591675
# LSTM Test Accuracy: 0.8514400124549866

# %%
# Step 4: GRU Model

from tensorflow.keras.layers import GRU

# Build model
gru_model = Sequential()
gru_model.add(Embedding(input_dim=vocab_size, output_dim=128, input_length=max_len))
gru_model.add(GRU(64))
gru_model.add(Dense(1, activation='sigmoid'))

# Compile
gru_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Summary
gru_model.summary()

# Train
history_gru = gru_model.fit(
    X_train, y_train,
    epochs=5,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 128ms/step - accuracy: 0.7965 - loss: 0.4273 - val_accuracy: 0.8518 - val_loss: 0.3650
# Epoch 2/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 127ms/step - accuracy: 0.9011 - loss: 0.2482 - val_accuracy: 0.8800 - val_loss: 0.3059
# Epoch 3/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 86s 134ms/step - accuracy: 0.9445 - loss: 0.1507 - val_accuracy: 0.8776 - val_loss: 0.3133
# Epoch 4/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 124ms/step - accuracy: 0.9708 - loss: 0.0874 - val_accuracy: 0.8688 - val_loss: 0.4027
# Epoch 5/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 125ms/step - accuracy: 0.9823 - loss: 0.0536 - val_accuracy: 0.8692 - val_loss: 0.4618

# %%
# Step 5: Evaluate GRU

loss_gru, acc_gru = gru_model.evaluate(X_test, y_test)

print("GRU Test Loss:", loss_gru)
print("GRU Test Accuracy:", acc_gru)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 24s 30ms/step - accuracy: 0.8677 - loss: 0.4745
# GRU Test Loss: 0.4744529724121094
# GRU Test Accuracy: 0.8677200078964233
